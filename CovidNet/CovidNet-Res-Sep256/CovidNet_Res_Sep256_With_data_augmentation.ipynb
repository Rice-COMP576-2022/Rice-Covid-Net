# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import pathlib
import random
import os
import h5py

import tensorflow.keras as keras
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet import ResNet101
from tensorflow.keras.applications.efficientnet import EfficientNetB0
from tensorflow.keras.applications.densenet import DenseNet121
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, cohen_kappa_score, roc_auc_score, confusion_matrix
from sklearn.metrics import classification_report
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, Conv2D, MaxPool2D, MaxPooling2D, DepthwiseConv2D, SeparableConv2D, Input, add, ZeroPadding2D
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras import datasets, layers, models

#Suppressing Warnings
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

tf.keras.backend.clear_session()

# pre-processing
train_path = '../../Covid19-dataset/train'
test_path = '../../Covid19-dataset/test'

img_size = 224
batch = 16

# Image loader
from tensorflow.keras.preprocessing.image import ImageDataGenerator

def generate_data(DIR):
    datagen = ImageDataGenerator(rescale=1./255.,
                                 rotation_range=10,
                                width_shift_range=10,
                                height_shift_range=10)
    
    generator = datagen.flow_from_directory(
        DIR,
        batch_size=batch,
        shuffle=True,
        seed=42,
        class_mode='categorical',
        target_size=(img_size, img_size),
        classes={'Normal': 0, 'Viral Pneumonia': 1,'Covid': 2}
    )
    return generator


train_generator = generate_data(train_path)
test_generator = generate_data(test_path)
# Out:
# Found 251 images belonging to 3 classes.
# Found 66 images belonging to 3 classes.

# %% [markdown]
# # Modelling

# %%
# base_model = ResNet50(weights='imagenet', include_top=False,
#                             input_shape=(img_size, img_size,3))

# # freeze extraction layers
# base_model.trainable = False

# # add custom top layers
# x = base_model.output
# x = GlobalAveragePooling2D()(x)
# x = Dense(512 , activation='relu')(x)
# predictions = Dense(3, activation='softmax')(x)
# model = Model(inputs=base_model.input, outputs=predictions)

# # confirm unfrozen layers
# for layer in model.layers:
#     if layer.trainable==True:
#         print(layer)

# %%
def conv_block(input_tensor,
               filters,
               kernel_size,
               strides=(2,2)):
    filter_1, filter_2 = filters
    x = SeparableConv2D(filters=filter_1, kernel_size=kernel_size, strides=(1, 1), activation='relu', padding='same')(input_tensor)
    x = BatchNormalization()(x)
    x = SeparableConv2D(filters=filter_2, kernel_size=kernel_size, strides=strides, activation='relu', padding='same')(x)
#     x = BatchNormalization()(x)
#     x = SeparableConv2D(filters=filter_3, kernel_size=kernel_size, strides=strides, padding='same')(x)
    shortcut = SeparableConv2D(filters=filter_2, kernel_size=kernel_size, strides=strides, padding='same')(input_tensor)
    x = add([x, shortcut])
    return Activation('relu')(x)

def identity_block(input_tensor,
               filters,
               kernel_size):
    filter_1, filter_2 = filters
    strides = (1, 1)
    x = SeparableConv2D(filters=filter_1, kernel_size=kernel_size, strides=strides, activation='relu', padding='same')(input_tensor)
    x = BatchNormalization()(x)
    x = SeparableConv2D(filters=filter_2, kernel_size=kernel_size, strides=strides, activation='relu', padding='same')(x)
#     x = BatchNormalization()(x)
#     x = SeparableConv2D(filters=filter_3, kernel_size=kernel_size, strides=strides, padding='same')(x)
    x = add([x, input_tensor])
    return Activation('relu')(x)

def build_model(input_shape):
    input_img = Input(shape=input_shape, name='ImageInput')
    x = Conv2D(32, 3, padding='same', kernel_initializer='he_normal')(input_img)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2))(x)
    
    x = conv_block(x, filters=[32, 128], kernel_size=3, strides=(1,1))
    x = identity_block(x, filters=[32, 128], kernel_size=3)
    x = MaxPooling2D((2, 2))(x)
    
    x = conv_block(x, filters=[64, 256], kernel_size=3)
    x = identity_block(x, filters=[64, 256], kernel_size=3)
    
    x = MaxPooling2D((4, 4))(x)
    x = Flatten()(x)
    #     x = identity_block(x, filters=[64, 256], kernel_size=3)
    
#     x = conv_block(x, filters=[128, 256], kernel_size=3)
#     x = identity_block(x, filters=[64, 256], kernel_size=3)
#     x = layers.GlobalMaxPooling2D()(x)

    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(128, activation='relu')(x)
    x = Dense(3, activation='softmax')(x)
    
    model = Model(inputs=input_img, outputs=x)
    return model

model = build_model(input_shape=(img_size, img_size, 3))

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  ImageInput (InputLayer)        [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 224, 224, 32  896         ['ImageInput[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 224, 224, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 224, 224, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 112, 112, 32  0           ['activation[0][0]']
#                                 )
#
#  separable_conv2d (SeparableCon  (None, 112, 112, 32  1344       ['max_pooling2d[0][0]']
#  v2D)                           )
#
#  batch_normalization_1 (BatchNo  (None, 112, 112, 32  128        ['separable_conv2d[0][0]']
#  rmalization)                   )
#
#  separable_conv2d_1 (SeparableC  (None, 112, 112, 12  4512       ['batch_normalization_1[0][0]']
#  onv2D)                         8)
#
#  separable_conv2d_2 (SeparableC  (None, 112, 112, 12  4512       ['max_pooling2d[0][0]']
#  onv2D)                         8)
#
#  add (Add)                      (None, 112, 112, 12  0           ['separable_conv2d_1[0][0]',
#                                 8)                                'separable_conv2d_2[0][0]']
#
#  activation_1 (Activation)      (None, 112, 112, 12  0           ['add[0][0]']
#                                 8)
#
#  separable_conv2d_3 (SeparableC  (None, 112, 112, 32  5280       ['activation_1[0][0]']
#  onv2D)                         )
#
#  batch_normalization_2 (BatchNo  (None, 112, 112, 32  128        ['separable_conv2d_3[0][0]']
#  rmalization)                   )
#
#  separable_conv2d_4 (SeparableC  (None, 112, 112, 12  4512       ['batch_normalization_2[0][0]']
#  onv2D)                         8)
#
#  add_1 (Add)                    (None, 112, 112, 12  0           ['separable_conv2d_4[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  activation_2 (Activation)      (None, 112, 112, 12  0           ['add_1[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 128)  0          ['activation_2[0][0]']
#
#  separable_conv2d_5 (SeparableC  (None, 56, 56, 64)  9408        ['max_pooling2d_1[0][0]']
#  onv2D)
#
#  batch_normalization_3 (BatchNo  (None, 56, 56, 64)  256         ['separable_conv2d_5[0][0]']
#  rmalization)
#
#  separable_conv2d_6 (SeparableC  (None, 28, 28, 256)  17216      ['batch_normalization_3[0][0]']
#  onv2D)
#
#  separable_conv2d_7 (SeparableC  (None, 28, 28, 256)  34176      ['max_pooling2d_1[0][0]']
#  onv2D)
#
#  add_2 (Add)                    (None, 28, 28, 256)  0           ['separable_conv2d_6[0][0]',
#                                                                   'separable_conv2d_7[0][0]']
#
#  activation_3 (Activation)      (None, 28, 28, 256)  0           ['add_2[0][0]']
#
#  separable_conv2d_8 (SeparableC  (None, 28, 28, 64)  18752       ['activation_3[0][0]']
#  onv2D)
#
#  batch_normalization_4 (BatchNo  (None, 28, 28, 64)  256         ['separable_conv2d_8[0][0]']
#  rmalization)
#
#  separable_conv2d_9 (SeparableC  (None, 28, 28, 256)  17216      ['batch_normalization_4[0][0]']
#  onv2D)
#
#  add_3 (Add)                    (None, 28, 28, 256)  0           ['separable_conv2d_9[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_4 (Activation)      (None, 28, 28, 256)  0           ['add_3[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 256)   0           ['activation_4[0][0]']
#
#  flatten (Flatten)              (None, 12544)        0           ['max_pooling2d_2[0][0]']
#
#  dense (Dense)                  (None, 512)          6423040     ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 512)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 128)          65664       ['dropout[0][0]']
#
#  dense_2 (Dense)                (None, 3)            387         ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 6,607,811
# Trainable params: 6,607,363
# Non-trainable params: 448
# __________________________________________________________________________________________________

# %% [markdown]
# ## Save our best model during training

# %%
callbacks = [EarlyStopping(monitor='val_loss', patience=5, verbose=1),
                ModelCheckpoint('model.hdf5',
                                 save_best_only=True)]

opt = Adam(learning_rate=0.0001, decay=1e-5)
model.compile(
  loss='categorical_crossentropy',
  optimizer=opt,
  metrics=['accuracy']
)

# %% [markdown]
# # Training the Model

# %%
history = model.fit(train_generator,
                    epochs = 100,
                    validation_data = test_generator,
                    verbose = True,
                   callbacks=callbacks)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 20s 1s/step - loss: 1.0060 - accuracy: 0.5378 - val_loss: 1.0959 - val_accuracy: 0.4242
# Epoch 2/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.7581 - accuracy: 0.7689 - val_loss: 1.0896 - val_accuracy: 0.3939
# Epoch 3/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4911 - accuracy: 0.8327 - val_loss: 1.0789 - val_accuracy: 0.4091
# Epoch 4/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3659 - accuracy: 0.8526 - val_loss: 1.0738 - val_accuracy: 0.3939
# Epoch 5/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.2955 - accuracy: 0.8805 - val_loss: 1.0634 - val_accuracy: 0.3939
# Epoch 6/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2877 - accuracy: 0.8685 - val_loss: 1.0508 - val_accuracy: 0.3939
# Epoch 7/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2526 - accuracy: 0.9084 - val_loss: 1.0463 - val_accuracy: 0.3939
# Epoch 8/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2148 - accuracy: 0.9163 - val_loss: 1.0169 - val_accuracy: 0.3939
# Epoch 9/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.1831 - accuracy: 0.9283 - val_loss: 1.0313 - val_accuracy: 0.3939
# Epoch 10/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1814 - accuracy: 0.9283 - val_loss: 1.0660 - val_accuracy: 0.3939
# Epoch 11/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1672 - accuracy: 0.9442 - val_loss: 0.9791 - val_accuracy: 0.3939
# Epoch 12/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2025 - accuracy: 0.9124 - val_loss: 1.0224 - val_accuracy: 0.3939
# Epoch 13/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1744 - accuracy: 0.9363 - val_loss: 1.0369 - val_accuracy: 0.3939
# Epoch 14/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1951 - accuracy: 0.9004 - val_loss: 0.9870 - val_accuracy: 0.3939
# Epoch 15/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1593 - accuracy: 0.9562 - val_loss: 1.0020 - val_accuracy: 0.3939
# Epoch 16/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1270 - accuracy: 0.9482 - val_loss: 0.9646 - val_accuracy: 0.3939
# Epoch 17/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1306 - accuracy: 0.9402 - val_loss: 1.0418 - val_accuracy: 0.3939
# Epoch 18/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1484 - accuracy: 0.9363 - val_loss: 0.9523 - val_accuracy: 0.3939
# Epoch 19/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.1573 - accuracy: 0.9283 - val_loss: 0.9313 - val_accuracy: 0.4242
# Epoch 20/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.1521 - accuracy: 0.9442 - val_loss: 0.9903 - val_accuracy: 0.3939
# Epoch 21/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.1339 - accuracy: 0.9522 - val_loss: 0.9566 - val_accuracy: 0.4242
# Epoch 22/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.1114 - accuracy: 0.9522 - val_loss: 0.9445 - val_accuracy: 0.4242
# Epoch 23/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0935 - accuracy: 0.9641 - val_loss: 0.7882 - val_accuracy: 0.5758
# Epoch 24/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.1227 - accuracy: 0.9363 - val_loss: 1.0511 - val_accuracy: 0.4091
# Epoch 25/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0899 - accuracy: 0.9721 - val_loss: 0.7320 - val_accuracy: 0.6515
# Epoch 26/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0838 - accuracy: 0.9522 - val_loss: 0.7966 - val_accuracy: 0.6667
# Epoch 27/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0972 - accuracy: 0.9641 - val_loss: 0.7044 - val_accuracy: 0.6970
# Epoch 28/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.1011 - accuracy: 0.9681 - val_loss: 0.6196 - val_accuracy: 0.7121
# Epoch 29/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0909 - accuracy: 0.9681 - val_loss: 0.5725 - val_accuracy: 0.7273
# Epoch 30/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0990 - accuracy: 0.9721 - val_loss: 0.5645 - val_accuracy: 0.7727
# Epoch 31/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1175 - accuracy: 0.9442 - val_loss: 0.4460 - val_accuracy: 0.8333
# Epoch 32/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0841 - accuracy: 0.9721 - val_loss: 0.4306 - val_accuracy: 0.8333
# Epoch 33/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0802 - accuracy: 0.9602 - val_loss: 0.3911 - val_accuracy: 0.8182
# Epoch 34/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0512 - accuracy: 0.9841 - val_loss: 0.2944 - val_accuracy: 0.9242
# Epoch 35/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.1070 - accuracy: 0.9482 - val_loss: 0.4102 - val_accuracy: 0.8333
# Epoch 36/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0467 - accuracy: 0.9841 - val_loss: 0.2600 - val_accuracy: 0.9242
# Epoch 37/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0853 - accuracy: 0.9681 - val_loss: 0.2404 - val_accuracy: 0.8939
# Epoch 38/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0790 - accuracy: 0.9602 - val_loss: 0.2366 - val_accuracy: 0.9394
# Epoch 39/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0446 - accuracy: 0.9880 - val_loss: 0.2516 - val_accuracy: 0.9091
# Epoch 40/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0698 - accuracy: 0.9721 - val_loss: 0.2107 - val_accuracy: 0.9091
# Epoch 41/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0708 - accuracy: 0.9641 - val_loss: 0.1902 - val_accuracy: 0.9394
# Epoch 42/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0830 - accuracy: 0.9721 - val_loss: 0.2488 - val_accuracy: 0.9394
# Epoch 43/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0633 - accuracy: 0.9841 - val_loss: 0.1607 - val_accuracy: 0.9697
# Epoch 44/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0788 - accuracy: 0.9641 - val_loss: 0.1775 - val_accuracy: 0.9242
# Epoch 45/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0409 - accuracy: 0.9841 - val_loss: 0.1485 - val_accuracy: 0.9394
# Epoch 46/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0432 - accuracy: 0.9841 - val_loss: 0.2385 - val_accuracy: 0.9394
# Epoch 47/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0386 - accuracy: 0.9880 - val_loss: 0.2093 - val_accuracy: 0.9394
# Epoch 48/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0463 - accuracy: 0.9841 - val_loss: 0.1761 - val_accuracy: 0.9697
# Epoch 49/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0523 - accuracy: 0.9721 - val_loss: 0.2744 - val_accuracy: 0.8939
# Epoch 50/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0615 - accuracy: 0.9880 - val_loss: 0.2906 - val_accuracy: 0.9091
# Epoch 50: early stopping

# %% [markdown]
# # Evaluation

# %%
from tensorflow.keras.models import load_model
import pandas as pd

# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history.history) 

# or save to csv: 
hist_csv_file = 'history.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

model = load_model('./model.hdf5')

def learning_curve(model_fit, key='accuracy', ylim=(0, 1.01)):
    plt.figure(figsize=(12,6))
    plt.plot(model_fit.history[key])
    plt.plot(model_fit.history['val_' + key])
    plt.title('Learning Curve')
    plt.ylabel(key.title())
    plt.xlabel('Epoch')
    plt.ylim(ylim)
    plt.legend(['train', 'val'], loc='best')
    plt.show()

# %% [markdown]
# ### Loading our best model

# %%
learning_curve(history,'loss', ylim=(0,2))
learning_curve(history, 'accuracy', ylim=(0,1))

# %%
test_loss, test_acc = model.evaluate(test_generator, steps=len(test_generator), verbose=1)
print('Loss: %.3f' % (test_loss * 100.0))
print('Accuracy: %.3f' % (test_acc * 100.0))
# Out:
# 5/5 [==============================] - 2s 394ms/step - loss: 0.1962 - accuracy: 0.9545
# Loss: 19.617
# Accuracy: 95.455
